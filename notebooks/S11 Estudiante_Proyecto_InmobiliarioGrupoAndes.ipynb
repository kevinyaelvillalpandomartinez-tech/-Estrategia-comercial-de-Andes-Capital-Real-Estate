# %% [markdown]
# # Hola! 😀
#
# Soy **Jaime Paz** y mis amigos me suelen llamar James! – *"Tranquilo, no juego en el Real Madrid"* ⚽😅. Sí, como el futbolista James Rodríguez, pero en versión científico de datos… y mejor no me digas como a él. 😉
#
# Como tu revisor en TripleTen, estoy aquí para ayudarte a pulir tu código y tu forma de trabajar con datos. Si algo necesita un ajuste, no te preocupes: la idea es que cada comentario te acerque más a cómo se trabaja en un entorno profesional y que tu proyecto brille con todo su potencial.
#
# Cada vez que encuentre un detalle importante en tu proyecto, te lo señalaré para que puedas corregirlo y seguir creciendo. Si en algún punto no logras resolver algo, también estoy para guiarte en próximos intentos de revisión. 🔁
#
# Es muy importante que, cuando veas mis comentarios, **no los muevas, no los modifiques y no los borres**. Así mantenemos un historial claro de lo que ya revisamos y de tus avances. ✅
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente tu proyecto para asegurar que cumpla con los requisitos y te daré comentarios usando el siguiente formato:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - ¡Excelente trabajo! Esta parte está bien implementada y contribuye de forma positiva al análisis o al proyecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Atención</b> ⚠️ - Esta parte funciona, pero todavía se puede reforzar para que quede más clara, más completa o más sólida.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>A resolver</b> ❗ - Aquí hay un punto importante por corregir porque afecta la validez del análisis, la implementación o la entrega.
# </div>
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
#
#
# <b>Éxito</b> ✅ - ¡Excelente trabajo! Tu proyecto es excepcional y has logrado cubrir los objetivos del mismo. Abajo he dejado mis comentarios y unas pequeñas recomendaciones para que tomes en cuenta en un futuro y te hagan ¡un máster en Data!
#
# ¡Felicidades!
#
# </div>

# %% [markdown]
# # 📊 Proyecto: Análisis Comercial Inmobiliario
#
# El sector inmobiliario necesita evaluar su **desempeño comercial** para comprender su crecimiento, rentabilidad y comportamiento de clientes.
#
# Se solicita construir un **dashboard ejecutivo** que permita analizar ventas, clientes y propiedades para apoyar decisiones estratégicas basadas en datos.

# %% [markdown]
# # 📂 Descripción de los Datasets
#
# 🔹 **hecho_ventas_propiedades**
# Tabla de hechos con las transacciones de venta (precio, cliente, propiedad, canal, fecha).
#
# 🔹 **dim_clientes**
# Información y segmentación de clientes.
#
# 🔹 **dim_propiedades**
# Características de las propiedades (tipo, tamaño, ubicación, etc).
#
# 🔹 **dim_fecha**
# Tabla calendario que deberá ser creada como parte del modelado.

# %% [markdown]
# # 🎯 Preguntas que el dashboard debe responder
#
# **Desempeño general**
#
# - ¿Cuál es el **ingreso total** generado por la empresa?
# - ¿Cuántas **propiedades se han vendido**?
# - ¿Cuál es el **precio promedio de venta**?
# - ¿Cuál es la **comisión total** generada por la empresa?
#
# **Análisis comercial**
#
# - ¿Qué **tipo de propiedad genera más ingresos**?
# - ¿Qué **segmento de clientes compra más propiedades**?
# - ¿Qué canal de venta **genera mayor ingresos**?
#
#
# **Análisis temporal**
#
# - ¿Cómo evolucionan las **ventas en el tiempo**?
# - ¿El negocio está **creciendo año contra año**?
# - ¿Cómo va el desempeño **acumulado del año actual (YTD)**?
#
# **Cohortes de clientes**
#
# - ¿Los clientes **vuelven a comprar** después de su primera compra?
# - ¿Qué **cohortes de clientes generan más compras/ingresos con el tiempo**?

# %% [markdown]
# ## 🧹 Paso 1: Limpieza de datos
#
# Antes del modelado, debes validar y depurar la información.
#
# ### Tipos de datos
#
# - `fecha_venta` debe estar en formato **Date**.
# - Los campos numéricos deben estar correctamente formateados.
# - `porcentaje_comision` debe estar en formato **porcentaje**.
#
# ### Valores nulos
#
# - Revisar valores **nulos** en las tablas.
# - Justificar si deben eliminarse o mantenerse.
#
# ### Duplicados
#
# - Validar que no existan duplicados en las claves primarias de:
#   - `dim_clientes`
#   - `dim_propiedades`

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 📅 Paso 2: Creación de tabla calendario
#
# Si vas a realizar el dashboard en **Power BI**, deberás crear una tabla calendario llamada **dim_fecha**.
#
# **Requisitos (solo para Power BI):**
#
# - Utilizar las funciones `CALENDAR` y `ADDCOLUMNS`.
# - El rango de fechas debe construirse dinámicamente desde la **fecha mínima** hasta la **fecha máxima** de ventas en `hecho_ventas_propiedades`.
# - Incluir como mínimo las siguientes columnas:
#   - Año
#   - Mes (nombre)
#   - Número de mes
#   - Año-Mes (formato `YYYY-MM`)
#
# > ⚠️ **Nota:**
# > Si utilizas **Tableau**, no necesitas crear esta tabla. Puedes usar directamente el campo `fecha_venta` de la tabla `hecho_ventas_propiedades`, ya que Tableau genera automáticamente las jerarquías de fecha.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🧩 Paso 3: Modelado de datos
#
# ### Modelo requerido: Esquema estrella
#
# El modelo debe estructurarse en formato estrella:
#
# - `hecho_ventas_propiedades` como tabla central.
# - Tablas dimensionales conectadas:
#   - `dim_clientes`
#   - `dim_propiedades`
#   - `dim_fecha` (creada por ti, en caso de que aplique)
#
# Requisitos de las relaciones:
#
# - Cardinalidad **uno a muchos (1:*)**
# - Dirección de filtro **simple (single)**
# - Relaciones basadas en las claves correctas
# - Todas las relaciones deben estar **activas**

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 📊 Paso 4: Creación de medidas
#
# En este paso deberás crear las **medidas necesarias para responder las preguntas de negocio del dashboard**.
#
# Las medidas pueden implementarse en **Power BI (DAX)** o como **Calculated Fields en Tableau**.
#
# ---
#
# ### 4.1 🔹 Medidas base
#
# Crear como mínimo las siguientes medidas:
#
# - **Ingreso Total** (suma del `precio_venta`)
# - **Cantidad de Ventas**
# - **Ticket Promedio**
# - **Comisión Total**
#
# Estas métricas permitirán analizar el desempeño general del negocio.
#
# ---
#
# ### 4.2 🔹 Medidas con contexto de filtro
#
# Debes crear **al menos 2 medidas** que modifiquen el contexto de filtro.
#
# En este caso se utilizarán **medidas de participación (%)**, que permiten entender **qué proporción del ingreso total aporta cada categoría**.
#
# Las medidas que deben construirse son:
#
# - **Participación de ingresos por tipo de propiedad**
# - **Participación de ingresos por canal de venta**
# - **Participación de ingresos por segmento de cliente**
#
# Para ello:
# - Modifica el contexto de filtro con las funciones propias de cada herramienta
#   - En Power BI, usa `CALCULATE`
#   - En Tableau, usa expresiones como `FIXED` (LOD)
#
# Elimina el filtro de la dimensión correspondiente para obtener el total
#
# Asegúrate de que el denominador represente el total sin el filtro de la categoría, mientras que el numerador sí lo conserva.
#
# Estas medidas se utilizarán principalmente como **tooltip o etiqueta adicional en los gráficos** del dashboard para complementar el análisis.
#
# ---
#
# ### 4.3 🔹 Inteligencia de tiempo
#
# Utilizando la tabla **`dim_fecha`** (Power BI) o las funciones de fecha en Tableau, debes crear al menos 2 de las siguientes medidas:
#
# - **Ventas Year to Date (YTD)**
# - **Ventas Month to Date (MTD)**
# - **Ventas del año anterior**
# - **Crecimiento Year over Year (YoY)**
#
# Estas métricas permitirán analizar la evolución del negocio en el tiempo.
#
# ---
#
# ### 4.4 🔹 Medidas para análisis de cohortes
#
# Debes crear cálculos que permitan analizar **si los clientes vuelven a comprar después de su primera compra**.
#
# ⚠️ Estos cálculos deben crearse como **columnas calculadas**, no como medidas.
# Todas deben crearse en la tabla **`hecho_ventas_propiedades`**.
#
# Debes crear como mínimo:
#
# - **Primera compra por cliente** → fecha mínima de compra de cada cliente.
# - **Mes Cohorte** → mes en que el cliente realizó su **primera compra** (mes de adquisición).
# - **Mes Venta** → mes en que ocurre cada transacción. Este campo permite identificar **cuándo el cliente vuelve a comprar** después de su primera compra.
#
# Estos cálculos permitirán construir una **matriz de cohortes** donde:
#
# - **Filas** representen el **mes de cohorte**
# - **Columnas** representen el **mes de venta**
# - **Valores** muestren **cantidad de ventas o ingresos**
#
# ---

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 📊 Paso 5: Estructura del reporte
#
# El dashboard debe contener **mínimo tres páginas**.
#
# ---
#
# ### 5.1 1️⃣ Overview Ejecutivo
#
# Debe mostrar **el desempeño general del negocio**.
#
# Incluir minimo 4 KPIs:
#
# - **KPIs principales**
#   - Ingreso Total
#   - Cantidad de Ventas
#   - Ticket Promedio
#   - Comisión Total
#
# - **Tendencia de ventas en el tiempo**
#
# - **Ingresos o ventas por ciudad**
#
# - **Crecimiento Year over Year (YoY)**
#
# ---
#
# ### 5.2 2️⃣ Análisis Comercial
#
# Debe analizar **qué productos, canales y clientes generan más ingresos**.
#
# Incluir:
#
# - **Ingreso por tipo de propiedad**
# - **Ventas o ingresos por canal de venta**
# - **Ventas o ingresos por segmento de cliente**
# - **Tabla con formato condicional (colores semáforo)**
#   Sugerencia de campos:
#   - tipo_propiedad
#   - Ingreso Total
#   - Cantidad Ventas
#   - Ticket Promedio
#   Aplicar **formato condicional** para resaltar las categorías con mayor desempeño.
#
# Se recomienda usar **tooltips con medidas de participación (%)**.
#
# ---
#
# ### 5.3 3️⃣ Análisis de Cohortes
#
# Debe analizar **recurrencia de clientes**.
#
# Incluir:
#
# - **Matriz de cohortes**
#   - Filas → Mes Cohorte
#   - Columnas → Mes Venta
#   - Valores → Cantidad Ventas o Ingreso Total
#
# Esto permitirá observar **si los clientes vuelven a comprar y comparar cohortes en el tiempo**.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 📝Paso 6:  Resumen Ejecutivo
#
#
# Escribe aquí un resumen con:
#
# - hallazgos clave
# - métricas principales
# - insights accionables
# - recomendaciones estratégicas
#
# Ejemplos:
#
# **Hallazgos clave**
# Hallazgos clave
# -El periodo analizado generó $6,012 millones en ingresos a través de aproximadamente 9 mil transacciones inmobiliarias, evidenciando un volumen comercial sólido.
# -Las casas constituyen el tipo de propiedad con mayor contribución al revenue, consolidándose como el principal motor de ingresos del portafolio.
# -Ciudad de México concentra el mayor volumen de operaciones, posicionándose como el mercado más relevante para la compañía.
# -El canal Corredor es el más eficiente en generación de ingresos, aportando la mayor participación en las ventas totales.
# -Los clientes captados durante el primer cuatrimestre de 2023 presentan los niveles más altos de recurrencia, manteniendo actividad e ingresos durante más periodos que las cohortes posteriores.
#
# **Métricas principales**
# -El segmento de clientes de primera compra concentra la mayor proporción de ingresos, lo que confirma la importancia de optimizar las estrategias de adquisición.
# -Las cohortes adquiridas entre enero y abril de 2023 muestran una retención significativamente superior, sugiriendo que las tácticas comerciales y de captación implementadas en ese periodo fueron más efectivas.
# -Aunque los ingresos mantienen una tendencia positiva (+1.11% YoY), el crecimiento es moderado, por lo que existen oportunidades para acelerar la expansión mediante una mejor conversión y retención.
# -La concentración de ventas en una sola ciudad y en un canal dominante representa una fortaleza, pero también una dependencia que podría incrementar el riesgo operativo.
#
# **Insights accionables**
# - El segmento de clientes de primera vez  concentra la mayor parte del ingreso.
# - Los clientes adquiridos en las cohortes de  muestran mayor recurrencia,Las cohortes de clientes captadas durante el primer cuatrimestre de 2023 presentan los niveles más altos de recurrencia, generando ingresos sostenidos a lo largo del tiempo. Este comportamiento indica una mejor retención y representa una oportunidad para identificar y replicar las estrategias de adquisición utilizadas en ese periodo.
# - Las ventas muestran un crecimiento/disminución de X% YoY de 1.11%
#
# **Recomendaciones estratégicas**
# -Priorizar la comercialización de casas, enfocando campañas, inventario y esfuerzos comerciales en la categoría de mayor rentabilidad.
# -Fortalecer y escalar el canal Corredor, identificando las mejores prácticas que impulsan su desempeño para replicarlas en otros canales.
# -Analizar las cohortes del primer cuatrimestre de 2023 para identificar patrones de adquisición y fidelización que puedan aplicarse a cohortes recientes.
# -Implementar programas de retención y seguimiento postventa para incrementar la recurrencia y el valor de vida del cliente (CLV).
# -Diversificar la presencia geográfica y los canales de venta, reduciendo la dependencia de mercados y fuentes de ingresos específicas.
# -Establecer metas orientadas a incrementar el crecimiento anual por encima del nivel actual mediante estrategias de cross-selling, referidos y optimización de la experiencia del cliente.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios._

# %% [markdown]
# ## 🚀 Entrega Final
#
# Comparte el acceso a tu proyecto final para revisión.
#
# Puedes entregar el proyecto utilizando **Power BI o Tableau**.
#
# Incluye **uno de los siguientes**:
#
# - 🔗 Link público del dashboard publicado en **Power BI Service o Tableau Public / Tableau Cloud**
# - 🔗 Link de **Google Drive o OneDrive** con el archivo `.pbix` del proyecto
# - ✅ Confirmación de que el archivo `.pbix` fue subido según las instrucciones del curso
#
# ### 📎 Enlace del proyecto
# ✏️ (Pega aquí tu link o escribe "Subi mi proyecto a la plataforma")

# %%
# (Pega aquí tu link)

# %% [markdown]
# | Paso | Criterio | Estado | Puntaje obtenido | Puntaje máximo | Comentario breve |
# |---|---|---|---:|---:|---|
# | Paso 1 | Tipos de datos | ✅ Logrado | 4 | 4 | Tienes los campos clave con tipos correctos, incluida la fecha de venta y la comisión porcentual. |
# | Paso 1 | Valores nulos | ❌ No logrado | 0 | 3 | No pude validar una revisión o bien una justificación clara de valores nulos. |
# | Paso 1 | Duplicados | ✅ Logrado | 3 | 3 | Aplicaste control de duplicados en las claves principales de clientes y propiedades. |
# | **Subtotal Paso 1** |  |  | **7** | **10** |  |
# | Paso 2 | Tabla `dim_fecha` | ✅ Logrado | 5 | 5 | Construiste una tabla calendario dinámica con el rango correcto de fechas. |
# | Paso 2 | Columnas obligatorias | ✅ Logrado | 5 | 5 | Incluiste Año, Mes, Número de mes y Año-Mes. |
# | **Subtotal Paso 2** |  |  | **10** | **10** |  |
# | Paso 3 | Definición de vistas | ✅ Logrado | 4 | 4 | Organizaste el dashboard en tres vistas alineadas al objetivo del negocio. |
# | Paso 3 | Selección de KPIs | ✅ Logrado | 4 | 4 | Elegiste indicadores útiles para desempeño, volumen, ticket y comisión. |
# | Paso 3 | Elección de gráficos | ✅ Logrado | 4 | 4 | Usaste visuales adecuados para tendencia, comparación y recurrencia. |
# | Paso 3 | Jerarquía visual | ✅ Logrado | 3 | 3 | La distribución general es clara y facilita la lectura de las prioridades del análisis. |
# | **Subtotal Paso 3** |  |  | **15** | **15** |  |
# | Paso 4 | Medidas base | ✅ Logrado | 5 | 5 | Construiste correctamente las medidas principales del negocio. |
# | Paso 4 | Medidas con contexto | ✅ Logrado | 5 | 5 | Tus participaciones por tipo, canal y segmento quedaron implementadas y utilizables. |
# | Paso 4 | Inteligencia de tiempo | 🟡 Recomendación | 3 | 5 | Tienes YTD, MTD, año anterior y YoY, pero te recomiendo revisar el cálculo o formato del YoY porque el valor mostrado como `1.11` no se interpreta correctamente como porcentaje. |
# | Paso 4 | Cohortes | 🟡 Recomendación | 4 | 5 | Creaste las columnas necesarias y la matriz funciona, aunque `Mes Venta` hoy actúa como desfase mensual y no como mes calendario de la transacción. |
# | **Subtotal Paso 4** |  |  | **17** | **20** |  |
# | Paso 5 | Vista 1 — Overview Ejecutivo | ✅ Logrado | 8 | 8 | Incluyes KPIs, tendencia temporal, comparación geográfica y crecimiento. |
# | Paso 5 | Vista 2 — Análisis Comercial | ✅ Logrado | 7 | 7 | Cubres tipo de propiedad, canal, segmento y una tabla con formato condicional. |
# | Paso 5 | Vista 3 — Cohortes | ✅ Logrado | 5 | 5 | Presentas una matriz funcional que permite observar recurrencia de clientes. |
# | **Subtotal Paso 5** |  |  | **20** | **20** |  |
# | Paso 6 | Hallazgos clave | ✅ Logrado | 5 | 5 | Identificaste ingresos, propiedad líder, ciudad principal y canal dominante. |
# | Paso 6 | Insights accionables | 🟡 Recomendación | 3 | 5 | Tus insights van en la dirección correcta, pero todavía queda un placeholder (`X%`) y una idea que conviene cerrar con más precisión. |
# | Paso 6 | Recomendaciones estratégicas | ✅ Logrado | 5 | 5 | Propusiste acciones concretas sobre producto, canal, retención y crecimiento. |
# | **Subtotal Paso 6** |  |  | **13** | **15** |  |
# | Paso 7 | Link del proyecto | ✅ Logrado | 5 | 5 | Tu entrega quedó accesible para revisión. |
# | Paso 7 | Entrega completa y verificable | ✅ Logrado | 5 | 5 | La evidencia entregada permitió revisar el trabajo de principio a fin. |
# | **Subtotal Paso 7** |  |  | **10** | **10** |  |
# | **Total final** |  |  | **92** | **100** |  |
#
# ## Subtotal Paso 1
#
# **7/10 pts**
#
# ## Comentario Paso 1
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Atención</b> ⚠️ - Resuelves bien los tipos de datos y el control de duplicados, lo cual le da solidez a tu base. Para cerrar este paso con más fuerza, te recomiendo documentar también cómo revisaste los valores nulos y qué decisión tomaste con ellos.
# </div>
#
# ## Subtotal Paso 2
#
# **10/10 pts**
#
# ## Comentario Paso 2
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - Construiste correctamente tu tabla calendario y además incluiste las columnas obligatorias con una lógica dinámica. Este paso quedó bien resuelto y te da una buena base para el análisis temporal.
# </div>
#
# ## Subtotal Paso 3
#
# **15/15 pts**
#
# ## Comentario Paso 3
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - Tu diseño estratégico está bien pensado: separaste claramente las vistas, seleccionaste KPIs relevantes y usaste gráficos coherentes con cada pregunta de negocio. La navegación y la jerarquía visual permiten entender rápido el foco de cada página.
# </div>
#
# ## Subtotal Paso 4
#
# **17/20 pts**
#
# ## Comentario Paso 4
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - Tu capa de medidas está bien construida y cubre lo esencial del proyecto. El punto a reforzar está en la consistencia del análisis temporal y de cohortes: te recomiendo revisar la presentación del YoY para que se lea como porcentaje válido y ajustar la definición de <b>Mes Venta</b> si quieres que represente el mes real de la transacción y no el desfase desde la primera compra.
# </div>
#
# ## Subtotal Paso 5
#
# **20/20 pts**
#
# ## Comentario Paso 5
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - La estructura del reporte cumple muy bien con lo solicitado. Tus tres vistas responden a objetivos distintos y complementarios, y cada una aporta valor real para entender desempeño, composición comercial y recurrencia.
# </div>
#
# ## Subtotal Paso 6
#
# **13/15 pts**
#
# ## Comentario Paso 6
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - Tu resumen ejecutivo tiene buenos hallazgos y recomendaciones útiles, especialmente en producto, canal y retención. Para dejarlo más profesional, te recomiendo depurar los placeholders pendientes y cerrar con más precisión la redacción de uno de los insights sobre crecimiento YoY.
# </div>
#
# ## Subtotal Paso 7
#
# **10/10 pts**
#
# ## Comentario Paso 7
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - Tu entrega fue suficiente para validar el proyecto completo. Eso facilita mucho la revisión y demuestra una buena organización al momento de presentar tu trabajo final.
# </div>
#
# ## Total final
#
# **92/100 pts** **EXCELENTE!!! 🥳🥳🥳**
#
# ## Conclusión final
#
# **Conclusión general:** Tu proyecto está bien resuelto y cumple con muy buen nivel tanto en construcción del dashboard como en lectura de negocio. Lograste responder las preguntas principales con una estructura clara, medidas útiles y visualizaciones adecuadas.
#
# **Observaciones principales:** Tus mayores oportunidades de mejora están en documentar mejor la limpieza de valores nulos, revisar la consistencia del indicador YoY y pulir un poco la definición técnica del campo usado para cohortes. También conviene cerrar algunos detalles de redacción en el resumen ejecutivo para que quede totalmente sólido.
#
# **Puntos fuertes:** Destacas en la organización del reporte, en la selección de KPIs, en la implementación de medidas base y de participación, y en la claridad del análisis comercial. Además, tus recomendaciones estratégicas están bien alineadas con los hallazgos que presentas.
#
# **Sugerencias de mejora:** Te recomiendo dejar trazable la revisión de nulos, validar que el crecimiento YoY se calcule y se muestre con el formato correcto, y ajustar el campo de cohortes si buscas representar el mes real de recompra. Con esos cambios, tu entrega subiría de nivel con bastante facilidad.
#
# **BUEN TRABAJO, KEVIN!!!** Hiciste un trabajo fuerte y bastante completo. Ya tienes una base técnica y analítica sólida; ahora toca afinar esos detalles de validación y consistencia para que tu dashboard no solo se vea bien, sino que también quede impecable en términos de interpretación y trazabilidad.
